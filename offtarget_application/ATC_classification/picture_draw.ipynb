# %%
import pandas as pd
import numpy as np

# %%
mlknn_offtarget_roc  = [0.6088526275659427, 0.6259888086717967, 0.5991734756931485, 0.603923826311416, 0.6091512198936024]
mlknn_offtarget_map = [0.3631648675398669, 0.39082476491074775, 0.38008004098502646, 0.3709334158936757, 0.37323366488467535]
mlknn_offtarget_rloss = [0.37436763421228697, 0.3661924379409932, 0.3799988968160934, 0.3837281075539759, 0.38112091625458716]

mlknn_ecfp_roc = [0.5826917243982842, 0.5523036554322993, 0.556870834849787, 0.5545614150098261, 0.5514086762912107]
mlknn_ecfp_map = [0.32684603423765257, 0.3053314022334973, 0.30439005459056073, 0.2997785741607996, 0.314473978574412]
mlknn_ecfp_rloss = [0.39505046575133307, 0.42133389250441294, 0.4158879114623333, 0.4212365147697521, 0.4222761743715497]

# %% [markdown]
# #### AUROC

# %%
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from statannotations.Annotator import Annotator 

roc_df = pd.DataFrame({
    'AUROC':mlknn_offtarget_roc+mlknn_ecfp_roc,
    'fold':['fold1','fold2','fold3','fold4','fold5']*2,
    'model':['MLKNN']*5+['ECFP_MLKNN']*5
})
palette=['#fbb4ae','#fed9a6']

fig,ax = plt.subplots(figsize=(4,5),dpi=300)
ax = sns.barplot(x='model',y='AUROC',data=roc_df,palette=palette, ci="sd",
                 capsize=.1,errwidth=1.0,errcolor="k",ax=ax,
                 **{"edgecolor":"k","linewidth":1}) 

box_pair = [(('MLKNN'),('ECFP_MLKNN'))]
annotator = Annotator(ax, data=roc_df, x='model', y='AUROC', pairs=box_pair)
annotator.configure(test='Mann-Whitney', text_format='star',line_height=0.03,line_width=1)
annotator.apply_and_annotate()

ax.set_ylabel('Metric value',fontsize=18)
ax.set_xlabel('Model',fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(np.arange(0.5, 0.72, 0.05), fontsize=14)
plt.ylim(0.5,0.7)
plt.title('AUROC (\u2191)',fontsize=18)
plt.show()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# MLKNN vs. ECFP_MLKNN: Mann-Whitney-Wilcoxon test two-sided, P_val:7.937e-03 U_stat=2.500e+01

# %% [markdown]
# #### mAP

# %%
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from statannotations.Annotator import Annotator 

map_df = pd.DataFrame({
    'map':mlknn_offtarget_map+mlknn_ecfp_map,
    'fold':['fold1','fold2','fold3','fold4','fold5']*2,
    'model':['MLKNN']*5+['ECFP_MLKNN']*5
})
palette=['#fbb4ae','#fed9a6']

fig,ax = plt.subplots(figsize=(4,5),dpi=300)
ax = sns.barplot(x='model',y='map',data=map_df,palette=palette, ci="sd",
                 capsize=.1,errwidth=1.0,errcolor="k",ax=ax,
                 **{"edgecolor":"k","linewidth":1}) 

box_pair = [(('MLKNN'),('ECFP_MLKNN'))]
annotator = Annotator(ax, data=map_df, x='model', y='map', pairs=box_pair)
annotator.configure(test='Mann-Whitney', text_format='star',line_height=0.03,line_width=1)
annotator.apply_and_annotate()

ax.set_ylabel('Metric value',fontsize=18)
ax.set_xlabel('Model',fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(np.arange(0.2, 0.52, 0.1), fontsize=14)
plt.ylim(0.2,0.5)
plt.title('mAP (\u2191)',fontsize=18)
plt.show()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# MLKNN vs. ECFP_MLKNN: Mann-Whitney-Wilcoxon test two-sided, P_val:7.937e-03 U_stat=2.500e+01

# %% [markdown]
# #### Rank Loss

# %%
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from statannotations.Annotator import Annotator 

rloss_df = pd.DataFrame({
    'rloss':mlknn_offtarget_rloss+mlknn_ecfp_rloss,
    'fold':['fold1','fold2','fold3','fold4','fold5']*2,
    'model':['MLKNN']*5+['ECFP_MLKNN']*5
})
palette=['#fbb4ae','#fed9a6']

fig,ax = plt.subplots(figsize=(4,5),dpi=300)
ax = sns.barplot(x='model',y='rloss',data=rloss_df,palette=palette, ci="sd",
                 capsize=.1,errwidth=1.0,errcolor="k",ax=ax,
                 **{"edgecolor":"k","linewidth":1}) 

box_pair = [(('MLKNN'),('ECFP_MLKNN'))]
annotator = Annotator(ax, data=rloss_df, x='model', y='rloss', pairs=box_pair)
annotator.configure(test='Mann-Whitney', text_format='star',line_height=0.03,line_width=1)
annotator.apply_and_annotate()

ax.set_ylabel('Metric value',fontsize=18)
ax.set_xlabel('Model',fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(np.arange(0.2, 0.52, 0.1), fontsize=14)
plt.ylim(0.2,0.5)
plt.title('Rank Loss (\u2193)',fontsize=18)
plt.show()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# MLKNN vs. ECFP_MLKNN: Mann-Whitney-Wilcoxon test two-sided, P_val:7.937e-03 U_stat=0.000e+00
