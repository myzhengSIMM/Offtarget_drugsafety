# %% [markdown]
# ### Use XGBoost to train toxic/non-toxic data

# %% [markdown]
# #### 1.Import related packages

# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier as xgb
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### 2.Import data

# %%
toxic_df = pd.read_csv('/home/liujin/Offtarget_drugsafety/offtarget_application/Toxicity_prediction/toxic_predict_data/toxic_offtarget_profile.csv')
not_toxic_df = pd.read_csv('/home/liujin/Offtarget_drugsafety/offtarget_application/Toxicity_prediction/toxic_predict_data/nontoxic_offtarget_profile.csv')
toxic_df['label'] = 1
not_toxic_df['label'] = 0

df = pd.concat([toxic_df, not_toxic_df], axis=0)
print(toxic_df.shape, not_toxic_df.shape, df.shape)

data_df = df.drop(['smiles','label'], axis=1)
print(data_df.shape)

#### 数据集划分
train_x, test_x, train_y, test_y = train_test_split(data_df, df['label'], test_size=0.2, random_state=999)
print(train_x.shape, test_x.shape, train_y.shape, test_y.shape)
print(data_df.shape)
print(len(df['label']))
# Out:
# (877, 244) (1229, 244) (2106, 244)
# (2106, 242)
# (1684, 242) (422, 242) (1684,) (422,)
# (2106, 242)
# 2106

# %% [markdown]
# #### 3.Hyperparameter search

# %%
import numpy as np
import os
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score
from sklearn.pipeline import Pipeline
import joblib
from sklearn.ensemble import RandomForestClassifier
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
def objective(trial,X,y):

    X_train, X_val, y_train, y_val = train_test_split(X,y,test_size=0.1,random_state=999) 
    

    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 1000,step=50),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 10),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'objective': 'binary:logistic',
        'random_state': 2023
    }

    dt_clf = xgb(**param)
    
    dt_clf.fit(X_train, y_train)
    pred_dt = dt_clf.predict(X_val) 
    
    proba = dt_clf.predict_proba(X_val)
    score = roc_auc_score(y_val, proba[:,1])

    return score

# %%
study = optuna.create_study(direction="maximize", study_name="XGBoost Classifier")
func = lambda trial: objective(trial, train_x, train_y)
study.optimize(func, n_trials=1000)
# Out:
# [I 2023-09-15 03:11:57,832] A new study created in memory with name: XGBoost Classifier
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:12:00,316] Trial 0 finished with value: 0.9039021549213745 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.0013453365039547275, 'subsample': 0.5304651327596935, 'colsample_bytree': 0.931249712504733, 'gamma': 1.441727782431127, 'reg_alpha': 0.7211588004238467, 'reg_lambda': 0.2907850779152277, 'min_child_weight': 1}. Best is trial 0 with value: 0.9039021549213745.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:12:00,956] Trial 1 finished with value: 0.8992428654630169 and parameters: {'n_estimators': 50, 'max_depth': 8, 'learning_rate': 0.09750687698029317, 'subsample': 0.9883291484765666, 'colsample_bytree': 0.7395051429161519, 'gamma': 1.0772527886304228, 'reg_alpha': 3.455479945562745, 'reg_lambda': 4.713131839219946, 'min_child_weight': 6}. Best is trial 0 with value: 0.9039021549213745.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:12:09,484] Trial 2 finished with value: 0.9097262667443214 and parameters: {'n_estimators': 650, 'max_depth': 10, 'learning_rate': 0.026370993460150656, 'subsample': 0.6279434089420575, 'colsample_bytree': 0.6543325547584586, 'gamma': 5.94307105330396, 'reg_alpha': 0.06343877721839641, 'reg_lambda': 8.709178628292143, 'min_child_weight': 3}. Best is trial 2 with value: 0.9097262667443214.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:12:16,296] Trial 3 finished with value: 0.9088526499708794 and parameters: {'n_estimators': 800, 'max_depth': 5, 'learning_rate': 0.08103501081394313, 'subsample': 0.7642839140502428, 'colsample_bytree': 0.5850408680455605, 'gamma': 3.247015371915701, 'reg_alpha': 3.9741096447433453, 'reg_lambda': 5.236321689364628, 'min_child_weight': 4}. Best is trial 2 with value: 0.9097262667443214.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:12:24,824] Trial 4 finished with value: 0.9071054164239953 and parameters: {'n_estimators': 850, 'max_depth': 6, 'learning_rate': 0.004667019522777901, 'subsample': 0.8292760865231077, 'colsample_bytree': 0.926387795636927, 'gamma': 3.810950112078247, 'reg_alpha': 4.5721063158362485, 'reg_lambda': 3.655573209630194, 'min_child_weight': 5}. Best is trial 2 with value: 0.9097262667443214.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:12:31,610] Trial 5 finished with value: 0.9082702387885847 and parameters: {'n_estimators': 550, 'max_depth': 8, 'learning_rate': 0.0014754147441619055, 'subsample': 0.5968638589999307, 'colsample_bytree': 0.7111924607940042, 'gamma': 8.114631730527917, 'reg_alpha': 0.2405372796128391, 'reg_lambda': 0.16761505183225833, 'min_child_weight': 1}. Best is trial 2 with value: 0.9097262667443214.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:12:34,984] Trial 6 finished with value: 0.9098718695398952 and parameters: {'n_estimators': 600, 'max_depth': 3, 'learning_rate': 0.012979520631064482, 'subsample': 0.9972238847801227, 'colsample_bytree': 0.7993760994324657, 'gamma': 7.392266354683787, 'reg_alpha': 1.079169571826919, 'reg_lambda': 6.10500121363216, 'min_child_weight': 9}. Best is trial 6 with value: 0.9098718695398952.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:12:42,946] Trial 7 finished with value: 0.9037565521258007 and parameters: {'n_estimators': 850, 'max_depth': 8, 'learning_rate': 0.009508938390128929, 'subsample': 0.9270749564990112, 'colsample_bytree': 0.576491104844181, 'gamma': 5.201557285936646, 'reg_alpha': 6.468129994509412, 'reg_lambda': 4.984247590536891, 'min_child_weight': 10}. Best is trial 6 with value: 0.9098718695398952.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:12:47,310] Trial 8 finished with value: 0.9037565521258007 and parameters: {'n_estimators': 500, 'max_depth': 10, 'learning_rate': 0.03718145046584384, 'subsample': 0.5525433247473397, 'colsample_bytree': 0.6624294204015708, 'gamma': 8.969524181851215, 'reg_alpha': 6.029240457360332, 'reg_lambda': 1.2747852692724138, 'min_child_weight': 8}. Best is trial 6 with value: 0.9098718695398952.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:12:54,223] Trial 9 finished with value: 0.8877402446126966 and parameters: {'n_estimators': 900, 'max_depth': 5, 'learning_rate': 0.003385995285949267, 'subsample': 0.7050239110914069, 'colsample_bytree': 0.5904575284874897, 'gamma': 7.723021533542481, 'reg_alpha': 9.988690224952165, 'reg_lambda': 9.533033025643165, 'min_child_weight': 7}. Best is trial 6 with value: 0.9098718695398952.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:12:56,418] Trial 10 finished with value: 0.9031741409435061 and parameters: {'n_estimators': 350, 'max_depth': 3, 'learning_rate': 0.014491102983641533, 'subsample': 0.8865397503181908, 'colsample_bytree': 0.8260940037600171, 'gamma': 9.743903570116272, 'reg_alpha': 2.3361841821043647, 'reg_lambda': 7.155401651898343, 'min_child_weight': 10}. Best is trial 6 with value: 0.9098718695398952.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:00,118] Trial 11 finished with value: 0.9132207338380897 and parameters: {'n_estimators': 650, 'max_depth': 3, 'learning_rate': 0.021836508684364184, 'subsample': 0.6616145144491018, 'colsample_bytree': 0.8085662043050795, 'gamma': 6.506459590904878, 'reg_alpha': 0.2829306841526477, 'reg_lambda': 8.921178744850803, 'min_child_weight': 4}. Best is trial 11 with value: 0.9132207338380897.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:04,199] Trial 12 finished with value: 0.9095806639487478 and parameters: {'n_estimators': 700, 'max_depth': 3, 'learning_rate': 0.014636921517130804, 'subsample': 0.6979022348890563, 'colsample_bytree': 0.8311453859263479, 'gamma': 6.606115474891769, 'reg_alpha': 1.8659776995220114, 'reg_lambda': 7.294728504721327, 'min_child_weight': 8}. Best is trial 11 with value: 0.9132207338380897.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:07,571] Trial 13 finished with value: 0.905066977285964 and parameters: {'n_estimators': 450, 'max_depth': 4, 'learning_rate': 0.008052225048316455, 'subsample': 0.9956406954421674, 'colsample_bytree': 0.802597292594179, 'gamma': 6.967482268720213, 'reg_alpha': 1.689037586220235, 'reg_lambda': 9.570788609531451, 'min_child_weight': 3}. Best is trial 11 with value: 0.9132207338380897.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:14,916] Trial 14 finished with value: 0.9089982527664531 and parameters: {'n_estimators': 1000, 'max_depth': 4, 'learning_rate': 0.026394095410494846, 'subsample': 0.8051881171520809, 'colsample_bytree': 0.8741184119954089, 'gamma': 7.8683004764672075, 'reg_alpha': 2.6345137151881834, 'reg_lambda': 7.620358943790856, 'min_child_weight': 5}. Best is trial 11 with value: 0.9132207338380897.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:18,784] Trial 15 finished with value: 0.9129295282469423 and parameters: {'n_estimators': 650, 'max_depth': 3, 'learning_rate': 0.04261990108798841, 'subsample': 0.669246045630807, 'colsample_bytree': 0.9692616171485249, 'gamma': 5.722784582127295, 'reg_alpha': 1.1010679580258063, 'reg_lambda': 6.504997163484402, 'min_child_weight': 8}. Best is trial 11 with value: 0.9132207338380897.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:21,435] Trial 16 finished with value: 0.9110366919044846 and parameters: {'n_estimators': 350, 'max_depth': 4, 'learning_rate': 0.046871037470379365, 'subsample': 0.6561595488773878, 'colsample_bytree': 0.999526435382663, 'gamma': 5.470638168325924, 'reg_alpha': 0.10289458025899012, 'reg_lambda': 8.523005317249984, 'min_child_weight': 7}. Best is trial 11 with value: 0.9132207338380897.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:26,710] Trial 17 finished with value: 0.9100174723354688 and parameters: {'n_estimators': 700, 'max_depth': 5, 'learning_rate': 0.055857197831317054, 'subsample': 0.7008923953772831, 'colsample_bytree': 0.5080322595458623, 'gamma': 4.430523188021848, 'reg_alpha': 2.7781643214881355, 'reg_lambda': 9.894347703842598, 'min_child_weight': 3}. Best is trial 11 with value: 0.9132207338380897.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:34,078] Trial 18 finished with value: 0.9089982527664532 and parameters: {'n_estimators': 750, 'max_depth': 6, 'learning_rate': 0.02296771372175258, 'subsample': 0.5049527479667428, 'colsample_bytree': 0.9962997861324064, 'gamma': 6.328817076818387, 'reg_alpha': 1.273314538348548, 'reg_lambda': 8.304863769373831, 'min_child_weight': 6}. Best is trial 11 with value: 0.9132207338380897.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:36,403] Trial 19 finished with value: 0.9140943506115317 and parameters: {'n_estimators': 400, 'max_depth': 3, 'learning_rate': 0.05181537697597494, 'subsample': 0.5989146117925527, 'colsample_bytree': 0.8864431866038065, 'gamma': 5.796000064950342, 'reg_alpha': 1.4170858988710702, 'reg_lambda': 6.390141464208599, 'min_child_weight': 4}. Best is trial 19 with value: 0.9140943506115317.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:39,259] Trial 20 finished with value: 0.9136575422248108 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.06417531700841687, 'subsample': 0.5791598953061872, 'colsample_bytree': 0.8810412678381091, 'gamma': 2.8090870303367432, 'reg_alpha': 3.0271755929181907, 'reg_lambda': 8.316217249252526, 'min_child_weight': 2}. Best is trial 19 with value: 0.9140943506115317.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:42,074] Trial 21 finished with value: 0.9129295282469423 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.06614345899071945, 'subsample': 0.5857751972655858, 'colsample_bytree': 0.8679344961495026, 'gamma': 2.7119718162263973, 'reg_alpha': 1.98507146109673, 'reg_lambda': 8.172629703391527, 'min_child_weight': 2}. Best is trial 19 with value: 0.9140943506115317.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:43,577] Trial 22 finished with value: 0.9081246359930111 and parameters: {'n_estimators': 250, 'max_depth': 3, 'learning_rate': 0.0384509133728302, 'subsample': 0.5916851581208041, 'colsample_bytree': 0.8866399328137786, 'gamma': 4.688509539200362, 'reg_alpha': 3.030741620933246, 'reg_lambda': 8.792530520503396, 'min_child_weight': 4}. Best is trial 19 with value: 0.9140943506115317.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:45,433] Trial 23 finished with value: 0.9104542807221898 and parameters: {'n_estimators': 250, 'max_depth': 4, 'learning_rate': 0.09353067114216473, 'subsample': 0.6341220245246525, 'colsample_bytree': 0.7747846378110148, 'gamma': 2.500181609098056, 'reg_alpha': 1.1161798305652382, 'reg_lambda': 7.509679891339887, 'min_child_weight': 2}. Best is trial 19 with value: 0.9140943506115317.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:49,709] Trial 24 finished with value: 0.901863715783343 and parameters: {'n_estimators': 500, 'max_depth': 5, 'learning_rate': 0.061860928475294834, 'subsample': 0.5615338107491876, 'colsample_bytree': 0.84697588262771, 'gamma': 4.668896456582649, 'reg_alpha': 1.7397416637195477, 'reg_lambda': 6.359882283450997, 'min_child_weight': 4}. Best is trial 19 with value: 0.9140943506115317.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:50,657] Trial 25 finished with value: 0.8961852067559698 and parameters: {'n_estimators': 150, 'max_depth': 3, 'learning_rate': 0.032047719338239855, 'subsample': 0.5042719410094982, 'colsample_bytree': 0.9126401101018965, 'gamma': 6.391153065964486, 'reg_alpha': 3.445303747368734, 'reg_lambda': 9.147002701077362, 'min_child_weight': 2}. Best is trial 19 with value: 0.9140943506115317.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:53,144] Trial 26 finished with value: 0.907251019219569 and parameters: {'n_estimators': 350, 'max_depth': 4, 'learning_rate': 0.06419946530585592, 'subsample': 0.6132457919223705, 'colsample_bytree': 0.9029549118607778, 'gamma': 0.09668108340892312, 'reg_alpha': 0.6774705056053261, 'reg_lambda': 7.913063718865957, 'min_child_weight': 4}. Best is trial 19 with value: 0.9140943506115317.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:13:58,553] Trial 27 finished with value: 0.9111822947000583 and parameters: {'n_estimators': 550, 'max_depth': 6, 'learning_rate': 0.02116961566552259, 'subsample': 0.5592083784642928, 'colsample_bytree': 0.8531722191559573, 'gamma': 3.721479628651948, 'reg_alpha': 2.3351837320039683, 'reg_lambda': 9.367772157484831, 'min_child_weight': 3}. Best is trial 19 with value: 0.9140943506115317.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:01,028] Trial 28 finished with value: 0.9098718695398952 and parameters: {'n_estimators': 450, 'max_depth': 3, 'learning_rate': 0.04810911589066984, 'subsample': 0.6401041722927221, 'colsample_bytree': 0.8053989231694144, 'gamma': 5.297762238945249, 'reg_alpha': 0.04713240313424727, 'reg_lambda': 8.893301387066998, 'min_child_weight': 5}. Best is trial 19 with value: 0.9140943506115317.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:03,410] Trial 29 finished with value: 0.9041933605125219 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.033985789721040514, 'subsample': 0.5336432728087283, 'colsample_bytree': 0.9399011771832152, 'gamma': 7.0899798023460825, 'reg_alpha': 0.7033942213909885, 'reg_lambda': 6.8276340996693605, 'min_child_weight': 1}. Best is trial 19 with value: 0.9140943506115317.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:05,977] Trial 30 finished with value: 0.9177344205008736 and parameters: {'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.07451031071115077, 'subsample': 0.5879813511894374, 'colsample_bytree': 0.879031311278867, 'gamma': 6.088165646116479, 'reg_alpha': 1.6233854786026591, 'reg_lambda': 8.102161050140964, 'min_child_weight': 2}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:08,536] Trial 31 finished with value: 0.9151135701805474 and parameters: {'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.07340621291859803, 'subsample': 0.5865882969588472, 'colsample_bytree': 0.8807087962477709, 'gamma': 5.8663986287220675, 'reg_alpha': 1.6734479458203475, 'reg_lambda': 7.86522422388358, 'min_child_weight': 2}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:09,485] Trial 32 finished with value: 0.9133663366336633 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.09868445313899682, 'subsample': 0.5922816795277894, 'colsample_bytree': 0.895670068222415, 'gamma': 5.594947101331538, 'reg_alpha': 1.6114184337016035, 'reg_lambda': 7.925380628992618, 'min_child_weight': 1}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:12,526] Trial 33 finished with value: 0.9116191030867793 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.07199335016769398, 'subsample': 0.5401590479574464, 'colsample_bytree': 0.863374437896078, 'gamma': 6.092839965682066, 'reg_alpha': 3.1763320449831833, 'reg_lambda': 8.074535754345984, 'min_child_weight': 2}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:14,682] Trial 34 finished with value: 0.9082702387885848 and parameters: {'n_estimators': 250, 'max_depth': 5, 'learning_rate': 0.07510914579304795, 'subsample': 0.566728778490235, 'colsample_bytree': 0.9426587838861584, 'gamma': 4.953057925293919, 'reg_alpha': 2.261456628038745, 'reg_lambda': 7.054540028155431, 'min_child_weight': 2}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:15,518] Trial 35 finished with value: 0.906814210832848 and parameters: {'n_estimators': 50, 'max_depth': 9, 'learning_rate': 0.052378043034508284, 'subsample': 0.6147584323647988, 'colsample_bytree': 0.9216488244656551, 'gamma': 4.2811918883722315, 'reg_alpha': 3.8604905473730136, 'reg_lambda': 5.979719779337854, 'min_child_weight': 1}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:20,036] Trial 36 finished with value: 0.9155503785672684 and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.0971777034526281, 'subsample': 0.5219824682225136, 'colsample_bytree': 0.8945123401547393, 'gamma': 5.865332505385707, 'reg_alpha': 2.6113044936300236, 'reg_lambda': 7.720958410316929, 'min_child_weight': 3}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:23,560] Trial 37 finished with value: 0.913075131042516 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.09682781668903277, 'subsample': 0.5301162934610045, 'colsample_bytree': 0.9408210069156482, 'gamma': 5.935492083388654, 'reg_alpha': 1.421038173352474, 'reg_lambda': 5.640385964253658, 'min_child_weight': 3}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:25,500] Trial 38 finished with value: 0.9105998835177636 and parameters: {'n_estimators': 150, 'max_depth': 8, 'learning_rate': 0.07810220031880886, 'subsample': 0.6138319654609193, 'colsample_bytree': 0.7612271113763374, 'gamma': 6.807185307130221, 'reg_alpha': 2.4409617090422486, 'reg_lambda': 6.994373409206029, 'min_child_weight': 3}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:29,746] Trial 39 finished with value: 0.9124927198602213 and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.05372667301937481, 'subsample': 0.5319261977963647, 'colsample_bytree': 0.9058193074571022, 'gamma': 5.108141923583862, 'reg_alpha': 0.9294526105115506, 'reg_lambda': 6.662771321384003, 'min_child_weight': 4}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:32,774] Trial 40 finished with value: 0.9057949912638322 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.07856289910302887, 'subsample': 0.5026021838323071, 'colsample_bytree': 0.8408886636348645, 'gamma': 7.3677166902756115, 'reg_alpha': 3.8240492804242754, 'reg_lambda': 5.5595895586248885, 'min_child_weight': 3}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:36,193] Trial 41 finished with value: 0.9113278974956319 and parameters: {'n_estimators': 400, 'max_depth': 5, 'learning_rate': 0.060917028719156066, 'subsample': 0.5797443563174683, 'colsample_bytree': 0.884827368986583, 'gamma': 4.039036417117422, 'reg_alpha': 2.7258844288695308, 'reg_lambda': 7.6765707498894376, 'min_child_weight': 2}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:42,335] Trial 42 finished with value: 0.9159871869539894 and parameters: {'n_estimators': 450, 'max_depth': 9, 'learning_rate': 0.09934434253575555, 'subsample': 0.5736889905771603, 'colsample_bytree': 0.860600004163041, 'gamma': 5.9098182669263295, 'reg_alpha': 1.9286551927957758, 'reg_lambda': 8.489221241167042, 'min_child_weight': 1}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:48,528] Trial 43 finished with value: 0.9079790331974374 and parameters: {'n_estimators': 450, 'max_depth': 9, 'learning_rate': 0.09796497369699313, 'subsample': 0.6073182423997955, 'colsample_bytree': 0.8564118331613869, 'gamma': 6.099223273881806, 'reg_alpha': 1.8467409728240542, 'reg_lambda': 8.607297319205383, 'min_child_weight': 1}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:14:56,110] Trial 44 finished with value: 0.9094350611531741 and parameters: {'n_estimators': 550, 'max_depth': 9, 'learning_rate': 0.08006989181876117, 'subsample': 0.5689970393804028, 'colsample_bytree': 0.8262568844201851, 'gamma': 5.686060243171556, 'reg_alpha': 0.6666108068691015, 'reg_lambda': 7.435500354890494, 'min_child_weight': 1}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:01,697] Trial 45 finished with value: 0.9088526499708794 and parameters: {'n_estimators': 500, 'max_depth': 10, 'learning_rate': 0.04729885023047043, 'subsample': 0.6321548709140613, 'colsample_bytree': 0.9168752599897118, 'gamma': 5.089344205441014, 'reg_alpha': 2.1100276633842587, 'reg_lambda': 7.189071596142482, 'min_child_weight': 5}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:04,293] Trial 46 finished with value: 0.9095806639487478 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.08206176437492557, 'subsample': 0.5501859796692838, 'colsample_bytree': 0.8784812711771259, 'gamma': 6.6283388297692465, 'reg_alpha': 1.5695643337902516, 'reg_lambda': 9.98513856866101, 'min_child_weight': 2}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:09,038] Trial 47 finished with value: 0.9047757716948166 and parameters: {'n_estimators': 350, 'max_depth': 8, 'learning_rate': 0.039138746454011775, 'subsample': 0.5986382813050563, 'colsample_bytree': 0.9576064036557358, 'gamma': 5.7816280963957976, 'reg_alpha': 4.390537523666635, 'reg_lambda': 9.012120429305483, 'min_child_weight': 1}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:14,055] Trial 48 finished with value: 0.9129295282469423 and parameters: {'n_estimators': 450, 'max_depth': 9, 'learning_rate': 0.05352388713967506, 'subsample': 0.5203324156483506, 'colsample_bytree': 0.7811037333771181, 'gamma': 7.126329800018056, 'reg_alpha': 1.2871845503397923, 'reg_lambda': 7.8127689557664075, 'min_child_weight': 4}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:16,962] Trial 49 finished with value: 0.914385556202679 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.06984740685374007, 'subsample': 0.5426058883768177, 'colsample_bytree': 0.8317447423382925, 'gamma': 6.212838624405131, 'reg_alpha': 0.6092336178980207, 'reg_lambda': 6.287068535258049, 'min_child_weight': 3}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:19,902] Trial 50 finished with value: 0.9075422248107163 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.07057088076224638, 'subsample': 0.5547248175772544, 'colsample_bytree': 0.8163632862702265, 'gamma': 7.564785034815213, 'reg_alpha': 0.717039141072608, 'reg_lambda': 4.593198608545905, 'min_child_weight': 3}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:23,932] Trial 51 finished with value: 0.9158415841584158 and parameters: {'n_estimators': 350, 'max_depth': 7, 'learning_rate': 0.09900676973953386, 'subsample': 0.5440581649065975, 'colsample_bytree': 0.8348497379733343, 'gamma': 6.191067502575895, 'reg_alpha': 0.43556906325701306, 'reg_lambda': 6.412418145089471, 'min_child_weight': 3}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:26,828] Trial 52 finished with value: 0.9116191030867792 and parameters: {'n_estimators': 250, 'max_depth': 7, 'learning_rate': 0.08550411201263379, 'subsample': 0.5202790504349286, 'colsample_bytree': 0.8368429409986053, 'gamma': 6.306196175190242, 'reg_alpha': 0.37204242760895156, 'reg_lambda': 8.459358588477384, 'min_child_weight': 2}. Best is trial 30 with value: 0.9177344205008736.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:30,222] Trial 53 finished with value: 0.9196272568433314 and parameters: {'n_estimators': 350, 'max_depth': 6, 'learning_rate': 0.0996053740039762, 'subsample': 0.5756449137263397, 'colsample_bytree': 0.8566702312929777, 'gamma': 6.661276071375766, 'reg_alpha': 0.39492532336057096, 'reg_lambda': 7.350479114350742, 'min_child_weight': 3}. Best is trial 53 with value: 0.9196272568433314.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:36,888] Trial 54 finished with value: 0.9151135701805474 and parameters: {'n_estimators': 600, 'max_depth': 7, 'learning_rate': 0.08837469067093373, 'subsample': 0.5719390031465229, 'colsample_bytree': 0.8569044697532701, 'gamma': 6.713497196726069, 'reg_alpha': 0.3772433410411828, 'reg_lambda': 7.3812505839185265, 'min_child_weight': 1}. Best is trial 53 with value: 0.9196272568433314.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:39,861] Trial 55 finished with value: 0.9148223645894001 and parameters: {'n_estimators': 350, 'max_depth': 5, 'learning_rate': 0.09708921695227611, 'subsample': 0.5447440961405491, 'colsample_bytree': 0.7888487905460042, 'gamma': 5.4155824871985825, 'reg_alpha': 1.0509708846408317, 'reg_lambda': 6.894952738918754, 'min_child_weight': 2}. Best is trial 53 with value: 0.9196272568433314.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:44,875] Trial 56 finished with value: 0.9103086779266162 and parameters: {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.05900082294819502, 'subsample': 0.5792802149276368, 'colsample_bytree': 0.8670438981250217, 'gamma': 8.192092833909872, 'reg_alpha': 0.09712622096809553, 'reg_lambda': 8.193597433474384, 'min_child_weight': 3}. Best is trial 53 with value: 0.9196272568433314.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:47,865] Trial 57 finished with value: 0.9158415841584159 and parameters: {'n_estimators': 350, 'max_depth': 5, 'learning_rate': 0.09972427739988297, 'subsample': 0.5192158823009809, 'colsample_bytree': 0.9007104313856604, 'gamma': 6.883574466023134, 'reg_alpha': 1.9732521459536752, 'reg_lambda': 7.628500192609533, 'min_child_weight': 6}. Best is trial 53 with value: 0.9196272568433314.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:52,154] Trial 58 finished with value: 0.9126383226557949 and parameters: {'n_estimators': 450, 'max_depth': 7, 'learning_rate': 0.08703866591425553, 'subsample': 0.5191081365926586, 'colsample_bytree': 0.9002581127996321, 'gamma': 6.89898831508328, 'reg_alpha': 2.035868043898254, 'reg_lambda': 8.617603305035024, 'min_child_weight': 6}. Best is trial 53 with value: 0.9196272568433314.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:55,351] Trial 59 finished with value: 0.9145311589982527 and parameters: {'n_estimators': 350, 'max_depth': 8, 'learning_rate': 0.09989982890307685, 'subsample': 0.5015499674036875, 'colsample_bytree': 0.8156777588691129, 'gamma': 6.401408985764142, 'reg_alpha': 1.0542931549740473, 'reg_lambda': 7.434551482740556, 'min_child_weight': 7}. Best is trial 53 with value: 0.9196272568433314.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:15:59,185] Trial 60 finished with value: 0.907251019219569 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.04414340200183886, 'subsample': 0.5620756823240399, 'colsample_bytree': 0.9238990201035483, 'gamma': 7.9958546142971425, 'reg_alpha': 2.496115830848416, 'reg_lambda': 6.586452127757289, 'min_child_weight': 6}. Best is trial 53 with value: 0.9196272568433314.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:16:01,345] Trial 61 finished with value: 0.9120559114735003 and parameters: {'n_estimators': 250, 'max_depth': 5, 'learning_rate': 0.07402051902812493, 'subsample': 0.5465854631687943, 'colsample_bytree': 0.8677385649437616, 'gamma': 6.0079159777874525, 'reg_alpha': 1.5215974780788415, 'reg_lambda': 7.785848848750137, 'min_child_weight': 5}. Best is trial 53 with value: 0.9196272568433314.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:16:04,314] Trial 62 finished with value: 0.9047757716948165 and parameters: {'n_estimators': 350, 'max_depth': 5, 'learning_rate': 0.06155769510202753, 'subsample': 0.5212160562752942, 'colsample_bytree': 0.8940884528219232, 'gamma': 6.545203490531966, 'reg_alpha': 2.039922202357457, 'reg_lambda': 8.236173363898862, 'min_child_weight': 2}. Best is trial 53 with value: 0.9196272568433314.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:16:06,855] Trial 63 finished with value: 0.9164239953407105 and parameters: {'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.08284966212437507, 'subsample': 0.5770676439570916, 'colsample_bytree': 0.8455922110791025, 'gamma': 5.591384691109383, 'reg_alpha': 1.294134291619024, 'reg_lambda': 7.574956384321737, 'min_child_weight': 7}. Best is trial 53 with value: 0.9196272568433314.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:16:09,626] Trial 64 finished with value: 0.9073966220151427 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.08395057035719247, 'subsample': 0.5633782179851329, 'colsample_bytree': 0.8451565428061435, 'gamma': 5.338062623397898, 'reg_alpha': 1.2937805490415497, 'reg_lambda': 7.263052970842174, 'min_child_weight': 7}. Best is trial 53 with value: 0.9196272568433314.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:16:11,507] Trial 65 finished with value: 0.9101630751310426 and parameters: {'n_estimators': 200, 'max_depth': 6, 'learning_rate': 0.062454490939650824, 'subsample': 0.6235537794618048, 'colsample_bytree': 0.8169846879817318, 'gamma': 7.134617812127869, 'reg_alpha': 0.36762475956753393, 'reg_lambda': 7.666094538359207, 'min_child_weight': 9}. Best is trial 53 with value: 0.9196272568433314.
# ...
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:56:35,998] Trial 478 finished with value: 0.9057949912638323 and parameters: {'n_estimators': 900, 'max_depth': 4, 'learning_rate': 0.008025279245965258, 'subsample': 0.5212137197683147, 'colsample_bytree': 0.8502691105515868, 'gamma': 6.8376384091024, 'reg_alpha': 1.35992208863962, 'reg_lambda': 8.260860388775976, 'min_child_weight': 6}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:56:42,427] Trial 479 finished with value: 0.9098718695398952 and parameters: {'n_estimators': 950, 'max_depth': 4, 'learning_rate': 0.02482340141171828, 'subsample': 0.5833891291072552, 'colsample_bytree': 0.8308774967491805, 'gamma': 6.704967146339872, 'reg_alpha': 1.658095269554063, 'reg_lambda': 4.712612084938071, 'min_child_weight': 9}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:56:49,165] Trial 480 finished with value: 0.9123471170646476 and parameters: {'n_estimators': 950, 'max_depth': 4, 'learning_rate': 0.021107713464009262, 'subsample': 0.5000925330180126, 'colsample_bytree': 0.8812680757261905, 'gamma': 5.587632233733868, 'reg_alpha': 0.5965133421072251, 'reg_lambda': 6.799378139803164, 'min_child_weight': 10}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:56:53,994] Trial 481 finished with value: 0.9136575422248107 and parameters: {'n_estimators': 900, 'max_depth': 3, 'learning_rate': 0.06482624387955405, 'subsample': 0.5307899145494548, 'colsample_bytree': 0.7399505399684314, 'gamma': 6.924141870188056, 'reg_alpha': 3.646171964487153, 'reg_lambda': 5.973139849406623, 'min_child_weight': 8}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:57:03,683] Trial 482 finished with value: 0.9094350611531742 and parameters: {'n_estimators': 1000, 'max_depth': 8, 'learning_rate': 0.08680158608167857, 'subsample': 0.5692465188573109, 'colsample_bytree': 0.8564996817845802, 'gamma': 6.562436413445062, 'reg_alpha': 2.5355407911784074, 'reg_lambda': 9.044462554655645, 'min_child_weight': 7}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:57:07,909] Trial 483 finished with value: 0.9124927198602213 and parameters: {'n_estimators': 500, 'max_depth': 5, 'learning_rate': 0.09971250674401536, 'subsample': 0.5566368597231177, 'colsample_bytree': 0.7887284174633102, 'gamma': 3.8929471984896087, 'reg_alpha': 0.3281007775256781, 'reg_lambda': 7.091494779389979, 'min_child_weight': 7}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:57:13,760] Trial 484 finished with value: 0.9123471170646476 and parameters: {'n_estimators': 850, 'max_depth': 4, 'learning_rate': 0.0798413062673063, 'subsample': 0.7957082418845843, 'colsample_bytree': 0.8384045303454817, 'gamma': 7.1547367329214175, 'reg_alpha': 0.8440575616174684, 'reg_lambda': 9.679932536880257, 'min_child_weight': 10}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:57:20,210] Trial 485 finished with value: 0.9116191030867793 and parameters: {'n_estimators': 900, 'max_depth': 4, 'learning_rate': 0.03350580922052454, 'subsample': 0.8628661016905945, 'colsample_bytree': 0.8642943041769521, 'gamma': 6.426361401652099, 'reg_alpha': 1.934442898961339, 'reg_lambda': 9.267352905897884, 'min_child_weight': 8}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:57:26,703] Trial 486 finished with value: 0.9145311589982528 and parameters: {'n_estimators': 950, 'max_depth': 4, 'learning_rate': 0.09158674217825911, 'subsample': 0.5142276478577286, 'colsample_bytree': 0.8238023941983074, 'gamma': 7.44812684386846, 'reg_alpha': 2.1669136799243747, 'reg_lambda': 5.5419120187442985, 'min_child_weight': 7}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:57:32,350] Trial 487 finished with value: 0.9111822947000582 and parameters: {'n_estimators': 1000, 'max_depth': 3, 'learning_rate': 0.03715698541501332, 'subsample': 0.5246632605353213, 'colsample_bytree': 0.8506109788874078, 'gamma': 6.730353273724933, 'reg_alpha': 1.1946927968500287, 'reg_lambda': 8.83650588507107, 'min_child_weight': 4}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:57:38,445] Trial 488 finished with value: 0.9120559114735003 and parameters: {'n_estimators': 950, 'max_depth': 4, 'learning_rate': 0.02867016076963144, 'subsample': 0.5434033177695062, 'colsample_bytree': 0.6014700043044721, 'gamma': 6.993102984078752, 'reg_alpha': 1.6026148524915005, 'reg_lambda': 5.7840307010800505, 'min_child_weight': 9}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:57:44,610] Trial 489 finished with value: 0.9114735002912056 and parameters: {'n_estimators': 900, 'max_depth': 4, 'learning_rate': 0.07310763246694754, 'subsample': 0.5370174540847334, 'colsample_bytree': 0.873321226158813, 'gamma': 2.5274182185638923, 'reg_alpha': 5.279965182659284, 'reg_lambda': 7.542873635356008, 'min_child_weight': 7}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:57:49,941] Trial 490 finished with value: 0.905940594059406 and parameters: {'n_estimators': 800, 'max_depth': 4, 'learning_rate': 0.041859578513701, 'subsample': 0.5136404124946095, 'colsample_bytree': 0.6558698139694721, 'gamma': 6.233433297813306, 'reg_alpha': 3.924349738257764, 'reg_lambda': 9.811769976089314, 'min_child_weight': 2}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:57:56,561] Trial 491 finished with value: 0.906377402446127 and parameters: {'n_estimators': 900, 'max_depth': 4, 'learning_rate': 0.012061458525864141, 'subsample': 0.613820097498589, 'colsample_bytree': 0.9004120283449192, 'gamma': 7.245603487749898, 'reg_alpha': 2.3084311288624177, 'reg_lambda': 9.478675755596075, 'min_child_weight': 6}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:58:01,454] Trial 492 finished with value: 0.9145311589982528 and parameters: {'n_estimators': 850, 'max_depth': 3, 'learning_rate': 0.08584764388316682, 'subsample': 0.5260993241668231, 'colsample_bytree': 0.8402492562755395, 'gamma': 6.642740331832768, 'reg_alpha': 1.7867079011464917, 'reg_lambda': 6.458115720856757, 'min_child_weight': 8}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:58:08,011] Trial 493 finished with value: 0.9197728596389051 and parameters: {'n_estimators': 950, 'max_depth': 4, 'learning_rate': 0.09212068739508547, 'subsample': 0.5457172347955126, 'colsample_bytree': 0.7984027805475425, 'gamma': 6.898577144028174, 'reg_alpha': 3.140566119131765, 'reg_lambda': 6.198951616191517, 'min_child_weight': 7}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:58:14,782] Trial 494 finished with value: 0.9154047757716948 and parameters: {'n_estimators': 950, 'max_depth': 4, 'learning_rate': 0.09240749804824552, 'subsample': 0.5523839688807862, 'colsample_bytree': 0.8777371273024794, 'gamma': 3.660462890419418, 'reg_alpha': 3.0031682170244784, 'reg_lambda': 9.184254334444185, 'min_child_weight': 7}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:58:21,538] Trial 495 finished with value: 0.9103086779266162 and parameters: {'n_estimators': 1000, 'max_depth': 4, 'learning_rate': 0.09183532571246047, 'subsample': 0.5442026542582291, 'colsample_bytree': 0.8040288689194641, 'gamma': 6.962587542155267, 'reg_alpha': 3.2697369761344115, 'reg_lambda': 6.08434515430138, 'min_child_weight': 7}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:58:28,241] Trial 496 finished with value: 0.9171520093185789 and parameters: {'n_estimators': 950, 'max_depth': 4, 'learning_rate': 0.09987375387508972, 'subsample': 0.6591912598710412, 'colsample_bytree': 0.7960984575829898, 'gamma': 7.118154917677518, 'reg_alpha': 2.9664009452572797, 'reg_lambda': 6.288912340593005, 'min_child_weight': 7}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:58:34,897] Trial 497 finished with value: 0.9073966220151427 and parameters: {'n_estimators': 950, 'max_depth': 4, 'learning_rate': 0.01312447653569666, 'subsample': 0.5367439461830712, 'colsample_bytree': 0.9464255817012418, 'gamma': 9.841681551737643, 'reg_alpha': 2.7490749765009213, 'reg_lambda': 4.22339915371346, 'min_child_weight': 7}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:58:41,833] Trial 498 finished with value: 0.9152591729761211 and parameters: {'n_estimators': 1000, 'max_depth': 4, 'learning_rate': 0.05489193711443988, 'subsample': 0.5536205879799392, 'colsample_bytree': 0.8638608859829177, 'gamma': 7.318253087835443, 'reg_alpha': 2.5744529184772786, 'reg_lambda': 0.42279004231193085, 'min_child_weight': 7}. Best is trial 258 with value: 0.9244321490972627.
# <ipython-input-7-2d8af442cae7>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2023-09-15 03:58:48,292] Trial 499 finished with value: 0.9127839254513687 and parameters: {'n_estimators': 950, 'max_depth': 4, 'learning_rate': 0.08373735135124685, 'subsample': 0.5629507585144499, 'colsample_bytree': 0.7921098420879922, 'gamma': 5.706306638380862, 'reg_alpha': 2.8121404223346675, 'reg_lambda': 6.581620256962859, 'min_child_weight': 7}. Best is trial 258 with value: 0.9244321490972627.

# %%
print(f"\tBest value (auc): {study.best_value:.5f}")
print(f"\tBest params:")
for key, value in study.best_params.items():
    print(f"\t\t{key}: {value}")

# %% [markdown]
# #### 4.Conduct five-fold cross-training based on the optimum hyperparameter

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score, balanced_accuracy_score, matthews_corrcoef
from xgboost import XGBClassifier as xgb

kf = KFold(n_splits=5, random_state=999, shuffle=True)

train_x, test_x, train_y, test_y = train_test_split(data_df, df['label'], test_size=0.2, random_state=999)

# model = xgb(**study.best_params)
model = xgb(n_estimators=850,
            max_depth=4,
            learning_rate=0.099,
            subsample=0.530,
            colsample_bytree=0.882,
            gamma=7.091,
            reg_alpha=1.879,
            reg_lambda=9.272,
            min_child_weight=7,
            random_state=2023)


acc_list = []
auc_list = []
f1_list = []
bacc_list = []
mcc_list = []

for train_index,val_index in kf.split(train_x):
    X_train, X_val = train_x.iloc[train_index], train_x.iloc[val_index]
    y_train, y_val = train_y.iloc[train_index], train_y.iloc[val_index]

    model.fit(X_train, y_train)
    y_pred = model.predict(test_x)
    y_prob = model.predict_proba(test_x)

    acc_list.append(accuracy_score(test_y, y_pred))
    auc_list.append(roc_auc_score(test_y, y_prob[:,1]))
    f1_list.append(f1_score(test_y, y_pred, average='binary'))
    bacc_list.append(balanced_accuracy_score(test_y, y_pred))
    mcc_list.append(matthews_corrcoef(test_y, y_pred))

print('accuracy_score:', np.mean(acc_list), np.std(acc_list))
print('roc_auc_score:', np.mean(auc_list), np.std(auc_list))
print('f1_score:', np.mean(f1_list), np.std(f1_list))
print('balanced_accuracy_score:', np.mean(bacc_list), np.std(bacc_list))
print('matthews_corrcoef:', np.mean(mcc_list), np.std(mcc_list))
# Out:
# accuracy_score: 0.8094786729857819 0.008687347289015808
# roc_auc_score: 0.904620566001163 0.0029184633611036015
# f1_score: 0.7537069147481992 0.01009569877297078
# balanced_accuracy_score: 0.8071864702461717 0.008358853664366825
# matthews_corrcoef: 0.6018335869584328 0.01705029776975143
